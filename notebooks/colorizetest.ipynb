# %%
import sys
sys.path.append(r"C:\Users\carol\OneDrive\Desktop\2D Color MPI")
from scripts import colorize
colorize.plot_vectors_2D(r"C:\Users\carol\OneDrive\Desktop\organized mpi images\2025-04-17_S12_Syn_I22")
colorize.colorize(r"C:\Users\carol\OneDrive\Desktop\organized mpi images\2025-04-17_S12_Syn_I22",
                   r"C:\Users\carol\OneDrive\Desktop\organized mpi images\2025-04-17_S12_Syn_I22")
# Out:
# x axis amplitudes (T): 0.005, 0.0075, 0.01, 0.0125, 0.015, 0.0175, 0.02, 0.0225, 0.025
# z axis amplitudes (T): 0.005, 0.0075, 0.01, 0.0125, 0.015, 0.0175, 0.02, 0.0225, 0.025
# 9 images of dimension (241, 480)
# Saved as matrix of dimension (9, 241, 480)
# C:\Users\carol\OneDrive\Desktop\2D Color MPI\scripts\colorize.py:368: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig_row.show()
# C:\Users\carol\OneDrive\Desktop\2D Color MPI\scripts\colorize.py:369: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig_overlay.show()
# x axis amplitudes (T): 0.005, 0.0075, 0.01, 0.0125, 0.015, 0.0175, 0.02, 0.0225, 0.025
# z axis amplitudes (T): 0.005, 0.0075, 0.01, 0.0125, 0.015, 0.0175, 0.02, 0.0225, 0.025
# 9 images of dimension (241, 480)
# Saved as matrix of dimension (9, 241, 480)
# Colorizing with: s12, syn, i22
# [[0.33985613 0.27806466 0.30168639]
#  [0.32567712 0.28850401 0.30023112]
#  [0.33858804 0.31235692 0.31964353]
# ...
