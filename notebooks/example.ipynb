# %%
import sys
sys.path.append(r"C:\Users\carol\OneDrive\Desktop\2D Color MPI")
from scripts import filter
filter.filter_images(r"C:\Users\carol\OneDrive\Desktop\organized mpi images\more amps\2025-05-11_S_O10\advanced_mpi_images\nrrd")
