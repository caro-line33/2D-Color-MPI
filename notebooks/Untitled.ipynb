# %%
import sys
sys.path.append(r"C:\Users\carol\OneDrive\Desktop\2D Color MPI")
from scripts import color2d
test = color2d.ImageStack(r"C:\Users\carol\OneDrive\Desktop\organized mpi images\more amps\2025-04-17_S12_Syn_I22")

# %%
test.display_images()
# Out:
# 9 images of dimension 241 x 480

# %%
test.visualize_vectors([160, 250, 90,160])

# %%
test.visualize_vectors([0, 100, 100,160])

# %%
test.visualize_vectors([260, 320, 90,190])

# %% [markdown]
# # test_visual.visualize_vectors([100, 170, 100,160])

# %%
test_visual.visualize_vectors([160, 170, 100,115], mask = False)

# %%
test_visual.visualize_vectors([215, 220, 115,120], mask=False)
