# %%
import sys
sys.path.append(r"C:\Users\carol\OneDrive\Desktop\2D Color MPI")
from scripts import filter
filter.filter_images(r"C:\Users\carol\OneDrive\Desktop\organized mpi images\Color 20 2575 (OG example)\advanced_mpi_images\nrrd")
