# %%
import sys
sys.path.append(r"C:\Users\carol\OneDrive\Desktop\2D Color MPI")
from scripts import color2d
test = color2d.Dataset(r"C:\Users\carol\OneDrive\Desktop\2D Color MPI\datasets\ni26o10")
test.append_data(r"C:\Users\carol\OneDrive\Desktop\organized mpi images\more amps\2025-04-17_N_I26_O10")
# Out:
# 9 images of dimension 241 x 480
# Enter ROI coordinates as x1,x2,y1,y2. Separate multiple ROIs with semicolons. 0,100,60,150;120,200,60,150;260,340,60,150
# ROI #1
# Enter a name for this ROI (or press Enter to skip):  n
# ROI #2
# Enter a name for this ROI (or press Enter to skip):  i26
# ROI #3
# Enter a name for this ROI (or press Enter to skip):  o10
# Adding data for 3 tracers: n, i26, o10
# n not in dataset. Add new? (Y/N)  y
# C:\Users\carol\miniconda3\envs\msdk\lib\site-packages\sklearn\decomposition\_nmf.py:2328: ConvergenceWarning: Maximum number of iterations 1000 reached. Increase it to improve convergence.
#   warnings.warn(
# i26 not in dataset. Add new? (Y/N)  y
# C:\Users\carol\miniconda3\envs\msdk\lib\site-packages\sklearn\decomposition\_nmf.py:2328: ConvergenceWarning: Maximum number of iterations 1000 reached. Increase it to improve convergence.
#   warnings.warn(
# o10 not in dataset. Add new? (Y/N)  y
# ...

# %%
test.colorize(r"C:\Users\carol\OneDrive\Desktop\organized mpi images\more amps\2025-04-17_N_I26_O10")
